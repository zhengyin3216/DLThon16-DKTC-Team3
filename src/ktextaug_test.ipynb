# %%
# pip install ktextaug

# %%
import ktextaug
print(ktextaug.__version__)
# Out:
# 0.1.9

# %%
sample_text = "지금 너 스스로를 죽여달라고 애원하는 것인가? 아닙니다. 죄송합니다. 죽을 거면 혼자 죽지 우리까지 사건에 휘말리게 해? 진짜 죽여버리고 싶게. 정말 잘못했습니다. 너가 선택해. 너가 죽을래 네 가족을 죽여줄까. 죄송합니다. 정말 잘못했습니다. 너에게는 선택권이 없어. 선택 못한다면 너와 네 가족까지 모조리 죽여버릴거야. 선택 못하겠습니다. 한번만 도와주세요. 그냥 다 죽여버려야겠군. 이의 없지? 제발 도와주세요."

# %% [markdown]
# ## **random_swap**

# %%
from ktextaug import TextAugmentation, random_swap
from ktextaug.tokenization_utils import Tokenizer
from random import Random

#text ="고래상어는 어류 중 가장 덩치가 큽니다. 하지만 상어라는 이름에 걸맞지 않게 온순해서 사람이 가까이 접근해 헤엄쳐도 경계하지 않고, 이빨 크기도 3mm 안팎이라고 합니다."
# get_tokenize_fn 함수의 사용예시
tokenizer = Tokenizer("mecab")
# print(type(tokenizer))
# print(tokenizer.tokenize(text))
# tokenize_fn = Tokenizer("komoran")
# print(tokenizer.tokenize(text))
tokenizer = Tokenizer("subword")
# print(tokenizer.tokenize(text))

# 이러한 <class 'function'> 또는 <class 'method'> 형태의 함수들은 패키지 내 함수나 TextAugmentation 클래스에 사용됩니다.

print(sample_text)
print("--------------------------")

agent = TextAugmentation(tokenizer=tokenizer,
#                         tokenize_fn="mecab",
                        num_processes=1)
print(agent.generate(sample_text,
                     mode="random_swap",
                     n_swaps=5))   

# print(random_swap(text_or_tokens=sample_text,
#                      tokenizer=tokenizer,
#                      rng=Random(2021),
#                      n_swaps=2))
# Out:
# /home/jjeong3150/anaconda3/envs/aiffel_learning_py312/lib/python3.12/site-packages/ktextaug/tokenization_utils.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# 지금 너 스스로를 죽여달라고 애원하는 것인가? 아닙니다. 죄송합니다. 죽을 거면 혼자 죽지 우리까지 사건에 휘말리게 해? 진짜 죽여버리고 싶게. 정말 잘못했습니다. 너가 선택해. 너가 죽을래 네 가족을 죽여줄까. 죄송합니다. 정말 잘못했습니다. 너에게는 선택권이 없어. 선택 못한다면 너와 네 가족까지 모조리 죽여버릴거야. 선택 못하겠습니다. 한번만 도와주세요. 그냥 다 죽여버려야겠군. 이의 없지? 제발 도와주세요.
# --------------------------
# 못한다 너 스스로를 죽여달라고 애원하는 것인가 ? 아닙니다 . 죄송합니다 . 죽을 이의면 혼자 죽지 우리까지 사건에 휘말리게 정말 ? 진짜 죽여버리고버려게 . 정말 잘못했습니다 . 너가 선택해 . 너가 죽을래 네면 죽여줄까 . 죄송합니다 . 해 잘못했습니다 . 너에게는 선택권이 없어 . 선택 지금 가족을 너와 네 가족까지 모조리 죽여버릴거야 . 선택 못하겠습니다 . 한번만 도와주세요 . 그냥 다 죽여 싶야겠군 . 거 없지 ? 제발 도와주세요 .

# %% [markdown]
# ## **random_insert**

# %%
from ktextaug import random_insert, random_delete, back_translate
print(sample_text)
print("--------------------------")

print(agent.generate(sample_text,
                     mode="random_insert",
                     n_inserts=2))   

print(random_insert(text_or_tokens=sample_text,
                     tokenizer=tokenizer, 
                     rng=Random(2021),
                     n_inserts=5))
# Out:
# 지금 너 스스로를 죽여달라고 애원하는 것인가? 아닙니다. 죄송합니다. 죽을 거면 혼자 죽지 우리까지 사건에 휘말리게 해? 진짜 죽여버리고 싶게. 정말 잘못했습니다. 너가 선택해. 너가 죽을래 네 가족을 죽여줄까. 죄송합니다. 정말 잘못했습니다. 너에게는 선택권이 없어. 선택 못한다면 너와 네 가족까지 모조리 죽여버릴거야. 선택 못하겠습니다. 한번만 도와주세요. 그냥 다 죽여버려야겠군. 이의 없지? 제발 도와주세요.
# --------------------------
# 지금 너 스스로를 죽여달라고 애원하는 것인가 ? 아닙니다 . 죄송합니다 . 죽을 거면 혼자 죽지 우리까지 사건에 휘말리게 해 ? 진짜 담 죽여버리고 싶게 . 정말 잘못했습니다 . 너가 선택해 . 너가 죽을래 네 가족을 죽여줄까 . 죄송합니다 . 정말 잘못했습니다 . 너에게는 선택권이 없어 . 선택 못한다면 너와 네 가족까지 모조리 죽여버릴거야 . 선택 못하겠습니다 . 한번만 도와주세요 . 그냥 다 죽여버려야겠군 죽집 . 이의 없지 ? 제발 도와주세요 .
# 지금 너 스스로를 죽여달라고 애원 사건에하는 것인가 ? 아닙니다 . 죄송합니다 . 죽을 거면 혼자 죽지 우리까지 사건에 휘말리게 해 ? 진짜 죽여버리고 싶게 . 정말 잘못했습니다 . 너가 채택 선택해 . 너가 죽을래 네 가족을 죽여줄까 . 죄송합니다 . 정말 잘못 도와주했습니다 . 너 그냥에게는 선택권이 없어 . 선택 못한다면 너와 네 가족까지 정말로 모조리 죽여버릴거야 . 선택 못하겠습니다 . 한번만 도와주세요 . 그냥 다 죽여버려야겠군 . 이의 없지 ? 제발 도와주세요 .

# %% [markdown]
# ## **random_delete**

# %%
print(sample_text)
print("--------------------------")

print(agent.generate(sample_text,
                     mode="random_delete",
                     prob=0.2))
# Out:
# 지금 너 스스로를 죽여달라고 애원하는 것인가? 아닙니다. 죄송합니다. 죽을 거면 혼자 죽지 우리까지 사건에 휘말리게 해? 진짜 죽여버리고 싶게. 정말 잘못했습니다. 너가 선택해. 너가 죽을래 네 가족을 죽여줄까. 죄송합니다. 정말 잘못했습니다. 너에게는 선택권이 없어. 선택 못한다면 너와 네 가족까지 모조리 죽여버릴거야. 선택 못하겠습니다. 한번만 도와주세요. 그냥 다 죽여버려야겠군. 이의 없지? 제발 도와주세요.
# --------------------------
# 지금 너 스스로를 죽여달라고 애원하는 것인가 아닙니다 죄송합니다 죽을 거면 혼자 죽지 우리까지 사건에 휘말리게 해 진짜 죽여버리고 싶 정말 잘못했습니다 너가 선택해 너 죽을래 죽여줄까 죄송합니다 정말 잘못했습니다 너 선택권이 없어 선택 못한다면 너와 네 가족까지 모조리 죽여버릴거야 선택 못하겠습니다 한번만 도와주 다 죽여버려야겠군 없지 제발 도와주

# %% [markdown]
# ## **back_translate**

# %%
print(sample_text)
print("--------------------------")

print(agent.generate(sample_text,
                     mode="back_translate",
                     target_language='ja'))
# Out:
# 지금 너 스스로를 죽여달라고 애원하는 것인가? 아닙니다. 죄송합니다. 죽을 거면 혼자 죽지 우리까지 사건에 휘말리게 해? 진짜 죽여버리고 싶게. 정말 잘못했습니다. 너가 선택해. 너가 죽을래 네 가족을 죽여줄까. 죄송합니다. 정말 잘못했습니다. 너에게는 선택권이 없어. 선택 못한다면 너와 네 가족까지 모조리 죽여버릴거야. 선택 못하겠습니다. 한번만 도와주세요. 그냥 다 죽여버려야겠군. 이의 없지? 제발 도와주세요.
# --------------------------
# 지금 나한테 자살하라고 애원하는 거야? 아니요. 정말 미안해요. 죽으려면 혼자 죽어야 합니다. 우리도 그 사건에 연루되어 있나요? 나는 정말로 당신을 죽이고 싶습니다. 나는 정말로 틀렸다. 당신이 선택합니다. 죽고 싶나요, 아니면 가족을 죽이고 싶나요? 정말 미안해요. 나는 정말로 틀렸다. 선택의 여지가 없습니다. 선택의 여지가 없다면 너와 네 가족 모두를 죽일 것이다. 나는 선택할 수 없습니다. 한 번만 도와주세요. 내 생각에는 모든 것을 죽이는 것이 낫다고 생각합니다. 이의가 있으신가요? 도와주세요.

# %%
print(sample_text)
print("--------------------------")
# agent = TextAugmentation(tokenizer="mecab")
print(agent.generate(sample_text,
                     mode="synonym_replace", n_syns=15))
# Out:
# 지금 너 스스로를 죽여달라고 애원하는 것인가? 아닙니다. 죄송합니다. 죽을 거면 혼자 죽지 우리까지 사건에 휘말리게 해? 진짜 죽여버리고 싶게. 정말 잘못했습니다. 너가 선택해. 너가 죽을래 네 가족을 죽여줄까. 죄송합니다. 정말 잘못했습니다. 너에게는 선택권이 없어. 선택 못한다면 너와 네 가족까지 모조리 죽여버릴거야. 선택 못하겠습니다. 한번만 도와주세요. 그냥 다 죽여버려야겠군. 이의 없지? 제발 도와주세요.
# --------------------------
# 지금 너 스스로를 죽달라고 애원하는 것인가 ? 아닙니다 . 죄송합니다 . 죽을 거면 혼자 죽지 우리까지 사건에 휘말리게 해 ? 진짜 죽버리고 싶게 . 정말 잘못했습니다 . 너가 선택해 . 너가 죽을래 네 가족을 죽줄까 . 죄송합니다 . 정말 잘못했습니다 . 너에게는 선택권이 없어 . 선택 못한다면 너와 네 가족까지 모조리 죽버릴거야 . 선택 못하겠습니다 . 한번만 도와주세요 . 그냥 다 죽버려야겠군 . 이의 없지 ? 제발 도와주세요 .
